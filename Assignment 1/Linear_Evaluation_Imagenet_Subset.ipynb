# %% [markdown]
# <a href="https://colab.research.google.com/github/tripuragorla/CMPE-297-Assignments/blob/main/Assignment%201/Linear_Evaluation_Imagenet_Subset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.0

# %%
# !nvidia-smi
# Out:
# Wed Sep 22 20:20:24 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Install wandb for experiment tracking
# !pip install --upgrade https://github.com/wandb/client/archive/feature/code-save.zip
# Out:
# Collecting https://github.com/wandb/client/archive/feature/code-save.zip
#   Downloading https://github.com/wandb/client/archive/feature/code-save.zip
#      - 10.4 MB 825 kB/s
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb==0.8.36) (7.1.2)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.24-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 5.2 MB/s
# Collecting gql==0.2.0
#   Downloading gql-0.2.0.tar.gz (18 kB)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.7/dist-packages (from wandb==0.8.36) (7.352.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb==0.8.36) (2.8.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb==0.8.36) (2.23.0)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.1-py3-none-any.whl (7.5 kB)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from wandb==0.8.36) (1.15.0)
# Collecting watchdog>=0.8.3
#   Downloading watchdog-2.1.5-py3-none-manylinux2014_x86_64.whl (75 kB)
#      |████████████████████████████████| 75 kB 3.8 MB/s
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.7/dist-packages (from wandb==0.8.36) (3.13)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb==0.8.36) (5.4.8)
# Collecting sentry-sdk>=0.4.0
#   Downloading sentry_sdk-1.4.1-py2.py3-none-any.whl (139 kB)
#      |████████████████████████████████| 139 kB 26.0 MB/s
# Collecting subprocess32>=3.5.3
#   Downloading subprocess32-3.5.4.tar.gz (97 kB)
#      |████████████████████████████████| 97 kB 6.5 MB/s
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting configparser>=3.8.1
#   Downloading configparser-5.0.2-py3-none-any.whl (19 kB)
# Collecting graphql-core<2,>=0.5.0
#   Downloading graphql-core-1.1.tar.gz (70 kB)
#      |████████████████████████████████| 70 kB 8.2 MB/s
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from gql==0.2.0->wandb==0.8.36) (2.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb==0.8.36) (3.7.4.3)
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->wandb==0.8.36) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->wandb==0.8.36) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->wandb==0.8.36) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->wandb==0.8.36) (3.0.4)
# Building wheels for collected packages: wandb, gql, graphql-core, subprocess32
#   Building wheel for wandb (setup.py) ... done
#   Created wheel for wandb: filename=wandb-0.8.36-py2.py3-none-any.whl size=1385054 sha256=1baec0d564c198dd8fe648f8eaf65a0568e64835b91fef1baaf68d9ba92ee434
#   Stored in directory: /root/.cache/pip/wheels/08/1e/c2/b01dd11de70589ef2c6305c9b94da5bdfa22fd99b08da54fcf
#   Building wheel for gql (setup.py) ... done
#   Created wheel for gql: filename=gql-0.2.0-py3-none-any.whl size=7639 sha256=9598e0aea38af9499be06727a93f4cd977985c03bccf503aa4dcd988b7831e64
#   Stored in directory: /root/.cache/pip/wheels/b6/9a/56/5456fd32264a8fc53eefcb2f74e24e99a7ef4eb40a9af5c905
#   Building wheel for graphql-core (setup.py) ... done
#   Created wheel for graphql-core: filename=graphql_core-1.1-py3-none-any.whl size=104649 sha256=b46404c464cd43f0ad63c871b3f1ec16498a0a2bf496433a068232a24fc224d8
#   Stored in directory: /root/.cache/pip/wheels/6b/fd/8c/a20dd591c1a554070cc33fb58042867e6ac1c85395abe2e57a
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=a43b744c7e02d55bdf4422f6226c39f3ac0df1de2200eae036ac83bf8799254b
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# Successfully built wandb gql graphql-core subprocess32
# Installing collected packages: smmap, graphql-core, gitdb, watchdog, subprocess32, shortuuid, sentry-sdk, gql, GitPython, docker-pycreds, configparser, wandb
# Successfully installed GitPython-3.1.24 configparser-5.0.2 docker-pycreds-0.4.0 gitdb-4.0.7 gql-0.2.0 graphql-core-1.1 sentry-sdk-1.4.1 shortuuid-1.0.1 smmap-4.0.0 subprocess32-3.5.4 wandb-0.8.36 watchdog-2.1.5

# %%
import wandb
wandb.login()
# Out:
# wandb: ERROR Not authenticated.  Copy a key from https://app.wandb.ai/authorize
# API Key: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
from google.colab import auth
auth.authenticate_user()

PROJECT_ID = "fast-ai-exploration" 
# !gcloud config set project $PROJECT_ID
# Out:
# Updated property [core/project].
# WARNING: You do not appear to have access to project [fast-ai-exploration] or it does not exist.

# %%
# !gsutil cp gs://resnet_simclr_imagenet/20200508-134915resnet_simclr.h5 .
# Out:
# AccessDeniedException: 403 tripurachandanagayatri.gorla@sjsu.edu does not have storage.objects.list access to the Google Cloud Storage bucket.

# %%
simclr_weights = wandb.restore("20200509-042927resnet_simclr.h5", run_path="sayakpaul/simclr/simclr-learning")

# %%
# Other imports
from sklearn.preprocessing import LabelEncoder
from sklearn.manifold import TSNE
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from wandb.keras import WandbCallback
import matplotlib.pyplot as plt
from imutils import paths
from tqdm import tqdm
import tensorflow as tf
import seaborn as sns
import numpy as np
import cv2

# Random seed fixation
tf.random.set_seed(666)
np.random.seed(666)

# %%
# Gather dataset
# !git clone https://github.com/thunderInfy/imagenet-5-categories
# Out:
# Cloning into 'imagenet-5-categories'...
# remote: Enumerating objects: 1532, done.
# remote: Total 1532 (delta 0), reused 0 (delta 0), pack-reused 1532
# Receiving objects: 100% (1532/1532), 88.56 MiB | 35.56 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# Train and test image paths
train_images = list(paths.list_images("imagenet-5-categories/train"))
test_images = list(paths.list_images("imagenet-5-categories/test"))
print(len(train_images), len(test_images))
# Out:
# 1250 250

# %%
# 10% of the dataset
train_images_10 = np.random.choice(train_images, len(train_images)//10)
len(train_images_10)
# Out:
# 125

# %%
def prepare_images(image_paths):
    images = []
    labels = []

    for image in tqdm(image_paths):
        image_pixels = plt.imread(image)
        image_pixels = cv2.resize(image_pixels, (224, 224))
        image_pixels = image_pixels/255.

        label = image.split("/")[2].split("_")[0]

        images.append(image_pixels)
        labels.append(label)

    images = np.array(images)
    labels = np.array(labels)

    print(images.shape, labels.shape)

    return images, labels

# %%
X_train, y_train = prepare_images(train_images_10)
X_test, y_test = prepare_images(test_images)
# Out:
# 100%|██████████| 125/125 [00:00<00:00, 174.39it/s]
# (125, 224, 224, 3) (125,)
# 100%|██████████| 250/250 [00:01<00:00, 180.27it/s]
# (250, 224, 224, 3) (250,)

# %%
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_test_enc = le.transform(y_test)

# %%
# Architecture utils
def get_resnet_simclr(hidden_1, hidden_2, hidden_3):
    base_model = tf.keras.applications.ResNet50(include_top=False, weights=None, input_shape=(224, 224, 3))
    base_model.trainable = True
    inputs = Input((224, 224, 3))
    h = base_model(inputs, training=False)
    h = GlobalAveragePooling2D()(h)

    projection_1 = Dense(hidden_1)(h)
    projection_1 = Activation("relu")(projection_1)
    projection_2 = Dense(hidden_2)(projection_1)
    projection_2 = Activation("relu")(projection_2)
    projection_3 = Dense(hidden_3)(projection_2)

    resnet_simclr = Model(inputs, projection_3)

    return resnet_simclr

# %%
resnet_simclr = get_resnet_simclr(256, 128, 50)
resnet_simclr.load_weights(simclr_weights.name)
resnet_simclr.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                6450
# =================================================================
# Total params: 24,151,602
# Trainable params: 24,098,482
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
def plot_training(H):
	with plt.xkcd():
		plt.plot(H.history["loss"], label="train_loss")
		plt.plot(H.history["val_loss"], label="val_loss")
		plt.plot(H.history["accuracy"], label="train_acc")
		plt.plot(H.history["val_accuracy"], label="val_acc")
		plt.title("Training Loss and Accuracy")
		plt.xlabel("Epoch #")
		plt.ylabel("Loss/Accuracy")
		plt.legend(loc="lower left")
		plt.show()

# %%
def get_linear_model(features):
    linear_model = Sequential([Dense(5, input_shape=(features, ), activation="softmax")])
    return linear_model

# %%
resnet_simclr.layers[1].trainable = False
resnet_simclr.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                6450
# =================================================================
# Total params: 24,151,602
# Trainable params: 563,890
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
# Encoder model with non-linear projections
projection = Model(resnet_simclr.input, resnet_simclr.layers[-2].output)

# Extract train and test features
train_features = projection.predict(X_train)
test_features = projection.predict(X_test)

print(train_features.shape, test_features.shape)
# Out:
# (125, 128) (250, 128)

# %%
# Early Stopping to prevent overfitting
es = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=2, verbose=2, restore_best_weights=True)

# %%
# Linear model
wandb.init(project="simclr", id="linear-eval-relu-last")

linear_model = get_linear_model(128)
linear_model.compile(loss="sparse_categorical_crossentropy", metrics=["accuracy"],
                     optimizer="adam")
history = linear_model.fit(train_features, y_train_enc,
                 validation_data=(test_features, y_test_enc),
                 batch_size=64,
                 epochs=35,
                 callbacks=[es, WandbCallback()])
plot_training(history)
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/tripuragorla/simclr" target="_blank">https://app.wandb.ai/tripuragorla/simclr</a><br/>
#                 Run page: <a href="https://app.wandb.ai/tripuragorla/simclr/runs/linear-eval-relu-last" target="_blank">https://app.wandb.ai/tripuragorla/simclr/runs/linear-eval-relu-last</a><br/>
# wandb: Wandb version 0.12.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# Epoch 1/35
# 2/2 [==============================] - 1s 218ms/step - loss: 3.5565 - accuracy: 0.1920 - val_loss: 3.1258 - val_accuracy: 0.1800
# Epoch 2/35
# 1/2 [==============>...............] - ETA: 0s - loss: 3.2164 - accuracy: 0.1719WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0021s vs `on_train_batch_end` time: 0.0047s). Check your callbacks.
# 2/2 [==============================] - 0s 36ms/step - loss: 3.3441 - accuracy: 0.2080 - val_loss: 2.9663 - val_accuracy: 0.1920
# Epoch 3/35
# 2/2 [==============================] - 0s 37ms/step - loss: 3.1689 - accuracy: 0.2000 - val_loss: 2.8244 - val_accuracy: 0.2000
# Epoch 4/35
# 2/2 [==============================] - 0s 47ms/step - loss: 3.0025 - accuracy: 0.2000 - val_loss: 2.6992 - val_accuracy: 0.2200
# Epoch 5/35
# 2/2 [==============================] - 0s 37ms/step - loss: 2.8621 - accuracy: 0.2000 - val_loss: 2.5902 - val_accuracy: 0.2240
# Epoch 6/35
# 2/2 [==============================] - 0s 44ms/step - loss: 2.7262 - accuracy: 0.2000 - val_loss: 2.4954 - val_accuracy: 0.2160
# Epoch 7/35
# 2/2 [==============================] - 0s 45ms/step - loss: 2.6235 - accuracy: 0.2000 - val_loss: 2.4140 - val_accuracy: 0.2400
# Epoch 8/35
# 2/2 [==============================] - 0s 43ms/step - loss: 2.5223 - accuracy: 0.2320 - val_loss: 2.3421 - val_accuracy: 0.2480
# Epoch 9/35
# 2/2 [==============================] - 0s 33ms/step - loss: 2.4392 - accuracy: 0.2480 - val_loss: 2.2791 - val_accuracy: 0.2640
# Epoch 10/35
# 2/2 [==============================] - 0s 37ms/step - loss: 2.3615 - accuracy: 0.2560 - val_loss: 2.2212 - val_accuracy: 0.2680
# Epoch 11/35
# 2/2 [==============================] - 0s 32ms/step - loss: 2.2852 - accuracy: 0.2560 - val_loss: 2.1673 - val_accuracy: 0.2720
# Epoch 12/35
# 2/2 [==============================] - 0s 36ms/step - loss: 2.2178 - accuracy: 0.2640 - val_loss: 2.1164 - val_accuracy: 0.2880
# Epoch 13/35
# 2/2 [==============================] - 0s 38ms/step - loss: 2.1533 - accuracy: 0.2640 - val_loss: 2.0682 - val_accuracy: 0.2960
# Epoch 14/35
# 2/2 [==============================] - 0s 35ms/step - loss: 2.0969 - accuracy: 0.2560 - val_loss: 2.0199 - val_accuracy: 0.3160
# Epoch 15/35
# 2/2 [==============================] - 0s 31ms/step - loss: 2.0369 - accuracy: 0.2640 - val_loss: 1.9742 - val_accuracy: 0.3080
# Epoch 16/35
# 2/2 [==============================] - 0s 35ms/step - loss: 1.9821 - accuracy: 0.2640 - val_loss: 1.9291 - val_accuracy: 0.3120
# Epoch 17/35
# 2/2 [==============================] - 0s 43ms/step - loss: 1.9323 - accuracy: 0.2720 - val_loss: 1.8874 - val_accuracy: 0.3240
# Epoch 18/35
# 2/2 [==============================] - 0s 43ms/step - loss: 1.8813 - accuracy: 0.2960 - val_loss: 1.8480 - val_accuracy: 0.3320
# Epoch 19/35
# 2/2 [==============================] - 0s 44ms/step - loss: 1.8354 - accuracy: 0.3040 - val_loss: 1.8110 - val_accuracy: 0.3360
# Epoch 20/35
# 2/2 [==============================] - 0s 31ms/step - loss: 1.7928 - accuracy: 0.3120 - val_loss: 1.7764 - val_accuracy: 0.3480
# Epoch 21/35
# 2/2 [==============================] - 0s 34ms/step - loss: 1.7528 - accuracy: 0.3440 - val_loss: 1.7448 - val_accuracy: 0.3480
# Epoch 22/35
# 2/2 [==============================] - 0s 44ms/step - loss: 1.7155 - accuracy: 0.3360 - val_loss: 1.7164 - val_accuracy: 0.3560
# Epoch 23/35
# 2/2 [==============================] - 0s 30ms/step - loss: 1.6816 - accuracy: 0.3360 - val_loss: 1.6900 - val_accuracy: 0.3600
# Epoch 24/35
# 2/2 [==============================] - 0s 48ms/step - loss: 1.6501 - accuracy: 0.3440 - val_loss: 1.6667 - val_accuracy: 0.3640
# Epoch 25/35
# 2/2 [==============================] - 0s 51ms/step - loss: 1.6181 - accuracy: 0.3440 - val_loss: 1.6455 - val_accuracy: 0.3800
# Epoch 26/35
# 2/2 [==============================] - 0s 38ms/step - loss: 1.5923 - accuracy: 0.3680 - val_loss: 1.6260 - val_accuracy: 0.3840
# Epoch 27/35
# 2/2 [==============================] - 0s 33ms/step - loss: 1.5636 - accuracy: 0.3760 - val_loss: 1.6094 - val_accuracy: 0.3920
# Epoch 28/35
# 2/2 [==============================] - 0s 48ms/step - loss: 1.5387 - accuracy: 0.3920 - val_loss: 1.5947 - val_accuracy: 0.3920
# Epoch 29/35
# 2/2 [==============================] - 0s 41ms/step - loss: 1.5128 - accuracy: 0.3920 - val_loss: 1.5807 - val_accuracy: 0.3960
# Epoch 30/35
# 2/2 [==============================] - 0s 35ms/step - loss: 1.4885 - accuracy: 0.4160 - val_loss: 1.5682 - val_accuracy: 0.3920
# Epoch 31/35
# 2/2 [==============================] - 0s 31ms/step - loss: 1.4680 - accuracy: 0.4240 - val_loss: 1.5562 - val_accuracy: 0.4000
# Epoch 32/35
# 2/2 [==============================] - 0s 43ms/step - loss: 1.4481 - accuracy: 0.4320 - val_loss: 1.5456 - val_accuracy: 0.4000
# Epoch 33/35
# 2/2 [==============================] - 0s 47ms/step - loss: 1.4275 - accuracy: 0.4480 - val_loss: 1.5353 - val_accuracy: 0.4000
# Epoch 34/35
# 2/2 [==============================] - 0s 31ms/step - loss: 1.4082 - accuracy: 0.4480 - val_loss: 1.5258 - val_accuracy: 0.4000
# Epoch 35/35
# 2/2 [==============================] - 0s 30ms/step - loss: 1.3913 - accuracy: 0.4560 - val_loss: 1.5162 - val_accuracy: 0.4040

# %%
# Encoder model with less non-linearity
projection = Model(resnet_simclr.input, resnet_simclr.layers[-4].output)

# Extract train and test features
train_features = projection.predict(X_train)
test_features = projection.predict(X_test)

print(train_features.shape, test_features.shape)
# Out:
# (125, 256) (250, 256)

# %%
wandb.init(project="simclr", id="linear-eval-relu-second-last")

linear_model = get_linear_model(256)
linear_model.compile(loss="sparse_categorical_crossentropy", metrics=["accuracy"],
                     optimizer="adam")
history = linear_model.fit(train_features, y_train_enc,
                 validation_data=(test_features, y_test_enc),
                 batch_size=64,
                 epochs=35,
                 callbacks=[es, WandbCallback()])
plot_training(history)
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/tripuragorla/simclr" target="_blank">https://app.wandb.ai/tripuragorla/simclr</a><br/>
#                 Run page: <a href="https://app.wandb.ai/tripuragorla/simclr/runs/linear-eval-relu-second-last" target="_blank">https://app.wandb.ai/tripuragorla/simclr/runs/linear-eval-relu-second-last</a><br/>
# wandb: Wandb version 0.12.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# Epoch 1/35
# 2/2 [==============================] - 0s 170ms/step - loss: 4.3567 - accuracy: 0.2400 - val_loss: 3.3990 - val_accuracy: 0.2760
# Epoch 2/35
# 1/2 [==============>...............] - ETA: 0s - loss: 4.1537 - accuracy: 0.1719WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0023s vs `on_train_batch_end` time: 0.0054s). Check your callbacks.
# 2/2 [==============================] - 0s 51ms/step - loss: 3.8325 - accuracy: 0.2400 - val_loss: 2.9888 - val_accuracy: 0.3120
# Epoch 3/35
# 2/2 [==============================] - 0s 30ms/step - loss: 3.3892 - accuracy: 0.2720 - val_loss: 2.6728 - val_accuracy: 0.3000
# Epoch 4/35
# 2/2 [==============================] - 0s 35ms/step - loss: 3.0157 - accuracy: 0.3120 - val_loss: 2.4338 - val_accuracy: 0.3000
# Epoch 5/35
# 2/2 [==============================] - 0s 41ms/step - loss: 2.7495 - accuracy: 0.3200 - val_loss: 2.2512 - val_accuracy: 0.3040
# Epoch 6/35
# 2/2 [==============================] - 0s 46ms/step - loss: 2.5107 - accuracy: 0.3120 - val_loss: 2.1080 - val_accuracy: 0.3000
# Epoch 7/35
# 2/2 [==============================] - 0s 34ms/step - loss: 2.3466 - accuracy: 0.2960 - val_loss: 2.0044 - val_accuracy: 0.3040
# Epoch 8/35
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2070 - accuracy: 0.2880 - val_loss: 1.9380 - val_accuracy: 0.3160
# Epoch 9/35
# 2/2 [==============================] - 0s 31ms/step - loss: 2.1021 - accuracy: 0.2720 - val_loss: 1.8989 - val_accuracy: 0.3200
# Epoch 10/35
# 2/2 [==============================] - 0s 32ms/step - loss: 2.0479 - accuracy: 0.2960 - val_loss: 1.8659 - val_accuracy: 0.3240
# Epoch 11/35
# 2/2 [==============================] - 0s 36ms/step - loss: 1.9699 - accuracy: 0.3360 - val_loss: 1.8184 - val_accuracy: 0.3480
# Epoch 12/35
# 2/2 [==============================] - 0s 33ms/step - loss: 1.9007 - accuracy: 0.3600 - val_loss: 1.7609 - val_accuracy: 0.3520
# Epoch 13/35
# 2/2 [==============================] - 0s 49ms/step - loss: 1.8241 - accuracy: 0.3760 - val_loss: 1.6877 - val_accuracy: 0.3680
# Epoch 14/35
# 2/2 [==============================] - 0s 33ms/step - loss: 1.7416 - accuracy: 0.3840 - val_loss: 1.6119 - val_accuracy: 0.3880
# Epoch 15/35
# 2/2 [==============================] - 0s 33ms/step - loss: 1.6645 - accuracy: 0.3920 - val_loss: 1.5416 - val_accuracy: 0.4040
# Epoch 16/35
# 2/2 [==============================] - 0s 34ms/step - loss: 1.5870 - accuracy: 0.4000 - val_loss: 1.4883 - val_accuracy: 0.4160
# Epoch 17/35
# 2/2 [==============================] - 0s 48ms/step - loss: 1.5284 - accuracy: 0.4480 - val_loss: 1.4512 - val_accuracy: 0.4320
# Epoch 18/35
# 2/2 [==============================] - 0s 34ms/step - loss: 1.4823 - accuracy: 0.4560 - val_loss: 1.4252 - val_accuracy: 0.4440
# Epoch 19/35
# 2/2 [==============================] - 0s 34ms/step - loss: 1.4454 - accuracy: 0.4720 - val_loss: 1.4081 - val_accuracy: 0.4520
# Epoch 20/35
# 2/2 [==============================] - 0s 34ms/step - loss: 1.4130 - accuracy: 0.4800 - val_loss: 1.3954 - val_accuracy: 0.4720
# Epoch 21/35
# 2/2 [==============================] - 0s 33ms/step - loss: 1.3821 - accuracy: 0.4880 - val_loss: 1.3875 - val_accuracy: 0.4640
# Epoch 22/35
# 2/2 [==============================] - 0s 49ms/step - loss: 1.3548 - accuracy: 0.5120 - val_loss: 1.3828 - val_accuracy: 0.4480
# Epoch 23/35
# 2/2 [==============================] - 0s 36ms/step - loss: 1.3247 - accuracy: 0.5040 - val_loss: 1.3791 - val_accuracy: 0.4280
# Epoch 24/35
# 2/2 [==============================] - 0s 42ms/step - loss: 1.3009 - accuracy: 0.4960 - val_loss: 1.3758 - val_accuracy: 0.4400
# Epoch 25/35
# 2/2 [==============================] - 0s 41ms/step - loss: 1.2788 - accuracy: 0.4960 - val_loss: 1.3727 - val_accuracy: 0.4480
# Epoch 26/35
# 2/2 [==============================] - 0s 35ms/step - loss: 1.2653 - accuracy: 0.4800 - val_loss: 1.3617 - val_accuracy: 0.4440
# Epoch 27/35
# 2/2 [==============================] - 0s 32ms/step - loss: 1.2526 - accuracy: 0.4880 - val_loss: 1.3563 - val_accuracy: 0.4400
# Epoch 28/35
# 2/2 [==============================] - 0s 32ms/step - loss: 1.2348 - accuracy: 0.4880 - val_loss: 1.3498 - val_accuracy: 0.4360
# Epoch 29/35
# 2/2 [==============================] - 0s 45ms/step - loss: 1.2228 - accuracy: 0.5120 - val_loss: 1.3371 - val_accuracy: 0.4440
# Epoch 30/35
# 2/2 [==============================] - 0s 40ms/step - loss: 1.2078 - accuracy: 0.5200 - val_loss: 1.3259 - val_accuracy: 0.4560
# Epoch 31/35
# 2/2 [==============================] - 0s 47ms/step - loss: 1.1953 - accuracy: 0.5360 - val_loss: 1.3177 - val_accuracy: 0.4640
# Epoch 32/35
# 2/2 [==============================] - 0s 38ms/step - loss: 1.1860 - accuracy: 0.5360 - val_loss: 1.3112 - val_accuracy: 0.4680
# Epoch 33/35
# 2/2 [==============================] - 0s 37ms/step - loss: 1.1769 - accuracy: 0.5360 - val_loss: 1.3071 - val_accuracy: 0.4920
# Epoch 34/35
# 2/2 [==============================] - 0s 32ms/step - loss: 1.1664 - accuracy: 0.5440 - val_loss: 1.3057 - val_accuracy: 0.4920
# Epoch 35/35
# 2/2 [==============================] - 0s 29ms/step - loss: 1.1586 - accuracy: 0.5680 - val_loss: 1.3011 - val_accuracy: 0.5000

# %%
# Encoder model with no projection
projection = Model(resnet_simclr.input, resnet_simclr.layers[-6].output)

# Extract train and test features
train_features = projection.predict(X_train)
test_features = projection.predict(X_test)

print(train_features.shape, test_features.shape)
# Out:
# (125, 2048) (250, 2048)

# %%
wandb.init(project="simclr", id="linear-eval-no-projections")

linear_model = get_linear_model(2048)
linear_model.compile(loss="sparse_categorical_crossentropy", metrics=["accuracy"],
                     optimizer="adam")
history = linear_model.fit(train_features, y_train_enc,
                 validation_data=(test_features, y_test_enc),
                 batch_size=64,
                 epochs=35,
                 callbacks=[es, WandbCallback()])
plot_training(history)
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/tripuragorla/simclr" target="_blank">https://app.wandb.ai/tripuragorla/simclr</a><br/>
#                 Run page: <a href="https://app.wandb.ai/tripuragorla/simclr/runs/linear-eval-no-projections" target="_blank">https://app.wandb.ai/tripuragorla/simclr/runs/linear-eval-no-projections</a><br/>
# wandb: Wandb version 0.12.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# Epoch 1/35
# 2/2 [==============================] - 1s 190ms/step - loss: 2.5198 - accuracy: 0.2080 - val_loss: 2.1180 - val_accuracy: 0.2800
# Epoch 2/35
# 1/2 [==============>...............] - ETA: 0s - loss: 2.1782 - accuracy: 0.2656WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0023s vs `on_train_batch_end` time: 0.0064s). Check your callbacks.
# 2/2 [==============================] - 0s 42ms/step - loss: 2.0863 - accuracy: 0.2800 - val_loss: 1.5497 - val_accuracy: 0.3120
# Epoch 3/35
# 2/2 [==============================] - 0s 33ms/step - loss: 1.7425 - accuracy: 0.3120 - val_loss: 1.7729 - val_accuracy: 0.2800
# Epoch 4/35
# 2/2 [==============================] - 0s 44ms/step - loss: 1.6362 - accuracy: 0.3680 - val_loss: 1.3703 - val_accuracy: 0.4320
# Streaming file created twice in same run: /content/wandb/run-20210922_202815-linear-eval-no-projections/wandb-events.jsonl
# Epoch 5/35
# 2/2 [==============================] - 0s 45ms/step - loss: 1.3898 - accuracy: 0.4560 - val_loss: 1.4138 - val_accuracy: 0.4480
# Epoch 6/35
# 2/2 [==============================] - 0s 41ms/step - loss: 1.4203 - accuracy: 0.4640 - val_loss: 1.2972 - val_accuracy: 0.4960
# Epoch 7/35
# 2/2 [==============================] - 0s 34ms/step - loss: 1.2823 - accuracy: 0.5040 - val_loss: 1.3178 - val_accuracy: 0.4320
# Epoch 8/35
# 2/2 [==============================] - 0s 46ms/step - loss: 1.2849 - accuracy: 0.5200 - val_loss: 1.3318 - val_accuracy: 0.4240
# Restoring model weights from the end of the best epoch.
# Epoch 00008: early stopping

# %%
wandb.init(project="simclr", id="visualization")
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/tripuragorla/simclr" target="_blank">https://app.wandb.ai/tripuragorla/simclr</a><br/>
#                 Run page: <a href="https://app.wandb.ai/tripuragorla/simclr/runs/visualization" target="_blank">https://app.wandb.ai/tripuragorla/simclr/runs/visualization</a><br/>
# wandb: Wandb version 0.12.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# W&B Run: https://app.wandb.ai/tripuragorla/simclr/runs/visualization

# %%
# Visualization of the representations
def plot_vecs_n_labels(v, labels):
    fig = plt.figure(figsize = (10, 10))
    sns.set_style("darkgrid")
    sns.scatterplot(v[:,0], v[:,1], hue=labels, legend='full', palette=sns.color_palette("bright", 5))
    plt.show()

    return fig

# %%
# Representations with no nonlinear projections
tsne = TSNE()
low_vectors = tsne.fit_transform(train_features)
fig = plot_vecs_n_labels(low_vectors, y_train_enc)
wandb.log({"no_no_linear_projection": fig})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# wandb: Wandb version 0.12.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# /usr/local/lib/python3.7/dist-packages/plotly/matplotlylib/mpltools.py:368: MatplotlibDeprecationWarning:
#
#
# The is_frame_like function was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#
# /usr/local/lib/python3.7/dist-packages/plotly/matplotlylib/renderer.py:474: UserWarning:
#
# Dang! That path collection is out of this world. I totally don't know what to do with it yet! Plotly can only import path collections linked to 'data' coordinates
#
# /usr/local/lib/python3.7/dist-packages/plotly/matplotlylib/renderer.py:512: UserWarning:
#
# I found a path object that I don't think is part of a bar chart. Ignoring.

# %%
# Representations with second last ReLU
tsne = TSNE()
projection = Model(resnet_simclr.input, resnet_simclr.layers[-4].output)
train_features = projection.predict(X_train)
low_vectors = tsne.fit_transform(train_features)
fig = plot_vecs_n_labels(low_vectors, y_train_enc)
wandb.log({"second_last_relu": fig})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# wandb: Wandb version 0.12.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# /usr/local/lib/python3.7/dist-packages/plotly/matplotlylib/mpltools.py:368: MatplotlibDeprecationWarning:
#
#
# The is_frame_like function was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#
# /usr/local/lib/python3.7/dist-packages/plotly/matplotlylib/renderer.py:474: UserWarning:
#
# Dang! That path collection is out of this world. I totally don't know what to do with it yet! Plotly can only import path collections linked to 'data' coordinates
#
# /usr/local/lib/python3.7/dist-packages/plotly/matplotlylib/renderer.py:512: UserWarning:
#
# I found a path object that I don't think is part of a bar chart. Ignoring.

# %%
# Representations with the last ReLU
tsne = TSNE()
projection = Model(resnet_simclr.input, resnet_simclr.layers[-2].output)
train_features = projection.predict(X_train)
low_vectors = tsne.fit_transform(train_features)
fig = plot_vecs_n_labels(low_vectors, y_train_enc)
wandb.log({"last_relu": fig})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# wandb: Wandb version 0.12.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# /usr/local/lib/python3.7/dist-packages/plotly/matplotlylib/mpltools.py:368: MatplotlibDeprecationWarning:
#
#
# The is_frame_like function was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#
# /usr/local/lib/python3.7/dist-packages/plotly/matplotlylib/renderer.py:474: UserWarning:
#
# Dang! That path collection is out of this world. I totally don't know what to do with it yet! Plotly can only import path collections linked to 'data' coordinates
#
# /usr/local/lib/python3.7/dist-packages/plotly/matplotlylib/renderer.py:512: UserWarning:
#
# I found a path object that I don't think is part of a bar chart. Ignoring.
